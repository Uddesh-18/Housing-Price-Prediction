# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,10)

# %%
df = pd.read_csv('Data.csv')
df.head()
# Out:
#     Location  Area     Price  New/Resale House_Type  bhk  bath        Floor  \
# 0  Mira Road   700   4760000           1  Apartment    1     1  More than 5
# 1   Goregaon  1296  18100000           1  Apartment    2     2  More than 5
# 2   Goregaon  1638  23800000           1  Apartment    3     2  More than 5
# 3   Goregaon  1465  21200000           1  Apartment    3     3  More than 5
# 4  Borivali    700   8600000           1  Apartment    1     1  More than 5
#
#    Age  Gym  Lift  Car_Parking  Security  Play_area  Clubhouse  Indoor_Games  \
# 0  NaN    1     1            1         0          0          0             0
# 1  NaN    1     1            1         1          1          1             1
# 2  NaN    1     1            1         1          1          1             1
# 3  NaN    1     1            1         1          1          1             1
# 4  NaN    1     1            1         1          1          1             1
#
#    Gas  Jogging_Track  Swimming_Pool
# ...

# %%
df.shape
# Out:
# (858, 19)

# %%
df1 = df.drop(['Lift','Security',"Play_area",'Clubhouse','Gas','Swimming_Pool'], axis='columns')
df1.head()
# Out:
#     Location  Area     Price  New/Resale House_Type  bhk  bath        Floor  \
# 0  Mira Road   700   4760000           1  Apartment    1     1  More than 5
# 1   Goregaon  1296  18100000           1  Apartment    2     2  More than 5
# 2   Goregaon  1638  23800000           1  Apartment    3     2  More than 5
# 3   Goregaon  1465  21200000           1  Apartment    3     3  More than 5
# 4  Borivali    700   8600000           1  Apartment    1     1  More than 5
#
#    Age  Gym  Car_Parking  Indoor_Games  Jogging_Track
# 0  NaN    1            1             0              0
# 1  NaN    1            1             1              1
# 2  NaN    1            1             1              1
# 3  NaN    1            1             1              1
# 4  NaN    1            1             1              1

# %%
df2=df1.drop(['House_Type','bath','Floor','Age'],axis= "columns")
df2.head(3)
# Out:
#     Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0  Mira Road   700   4760000           1    1    1            1             0
# 1   Goregaon  1296  18100000           1    2    1            1             1
# 2   Goregaon  1638  23800000           1    3    1            1             1
#
#    Jogging_Track
# 0              0
# 1              1
# 2              1

# %%
df2.isnull().sum()
# Out:
# Location         0
# Area             0
# Price            0
# New/Resale       0
# bhk              0
# Gym              0
# Car_Parking      0
# Indoor_Games     0
# Jogging_Track    0
# dtype: int64

# %%
df2['bhk'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
len(df2.Location.unique())
# Out:
# 158

# %%
df2['Location'].unique()
# Out:
# array(['Mira Road', 'Goregaon', 'Borivali ', 'Malad ', 'Malad',
#        'Kandivali ', 'Borivali', 'Kandivali', 'Andheri', 'Kharghar',
#        'Wadala', 'Ulwe', 'Dahisar', 'kandivali', 'Bhandup', 'Santacruz',
#        'Kanjurmarg', 'I C Colony', 'Marol', 'Parel', 'Lower Parel',
#        'Worli', 'Jogeshwari', 'Chembur Shell Colony', 'Central Avenue',
#        'Chembur', 'Diamond Market Road', 'Mulund', 'Nalasopara',
#        'raheja vihar', 'Powai Lake', 'MHADA Colony 20', 'Goregaon East',
#        'Tolaram Colony', 'Taloja', 'Thane', 'Vangani',
#        'Sector 20 Kharghar', 'Sector 5 Ulwe', 'Sector12 New Panvel',
#        'Sector 17 Ulwe', 'Sector9 Kamothe', 'Sector 19 Kharghar',
#        'Navi Basti', 'Sector12 Kamothe', 'Vasai', 'Ghatkopar', 'Tardeo',
#        'Thane West', 'Napeansea Road', 'Mahalaxmi', 'Nala Sopara',
#        'Kalyan West', 'Borivali East', 'Dahisar West', 'Nerul',
#        'Kandivali East', 'Sector-3 Ulwe', 'Mulund West', 'Natakwala Lane',
# ...

# %%
df2['Car_Parking'].unique()
# Out:
# array([1, 0])

# %%
df2[df2.bhk>=5]
# Out:
#       Location  Area      Price  New/Resale  bhk  Gym  Car_Parking  \
# 88       Thane  5245   90000000           1    5    1            1
# 291      Parel  2670   92500000           0    5    1            1
# 301     mumbai  2000   70000000           0    6    1            1
# 316     Kalyan  7000   50000000           0    6    0            1
# 498      Thane  5245   90000000           1    5    1            1
# 766   Kharghar  4000   28000000           0    5    1            1
# 848  Yari Road  2320  100000000           0    5    1            0
# 849  Yari Road  3320  145000000           0    5    1            0
#
#      Indoor_Games  Jogging_Track
# 88              1              1
# 291             1              1
# 301             0              0
# 316             0              0
# 498             1              1
# 766             0              0
# 848             0              0
# 849             0              0

# %%
df2.Area.unique()
# Out:
# array([ 700, 1296, 1638, 1465, 2030, 1450, 1100,  800, 1500, 1962,  950,
#        1440, 1200, 1785,  775,  765,  910,  640, 1264, 1056, 1810, 1656,
#        3888, 1114, 3585, 1404, 1620, 2780, 1672, 1250, 1840, 1170,  310,
#        1245, 1153,  573, 1135, 1060,  560, 1150, 1054, 1695, 1579, 2153,
#        1872, 1717, 1675, 1457,  425,  575,  400,  300,  650, 1600,  860,
#        1320, 2826, 2880,  997, 1038,  600, 2800, 1400, 1412,  545,  585,
#        1000, 1050, 1014,  900, 1550, 5245,  529,  530, 1260,  690, 1240,
#        1265, 2014, 1503, 1903, 1376, 3600, 1706,  686, 1005, 1220, 1189,
#        1055,  710,  417,  999, 1080, 1300,  738,  510,  670, 2710, 1388,
#        3638, 1700, 2450, 1165, 1025,  450,  603, 1340, 1160,  610,  850,
#        1095,  500,  635, 1065, 1251, 1136, 1125, 1098,  735, 1090, 1117,
#         675, 1075, 1070, 1182,  911,  555,  550, 1472,  370,  715, 1771,
#        1650,  816,  810,  473, 1016,  785, 1290, 1227, 1630, 2000,  525,
# ...

# %%
df3= df2.copy()
df3['price_per_sqrt'] = df3['Price']/df2['Area']
df3.head()
# Out:
#     Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0  Mira Road   700   4760000           1    1    1            1             0
# 1   Goregaon  1296  18100000           1    2    1            1             1
# 2   Goregaon  1638  23800000           1    3    1            1             1
# 3   Goregaon  1465  21200000           1    3    1            1             1
# 4  Borivali    700   8600000           1    1    1            1             1
#
#    Jogging_Track  price_per_sqrt
# 0              0     6800.000000
# 1              1    13966.049383
# 2              1    14529.914530
# 3              1    14470.989761
# 4              1    12285.714286

# %%
df3.Location = df3.Location.apply(lambda x: x.strip())
location_stats = df3.groupby('Location')['Location'].agg('count').sort_values(ascending=False)
location_stats
# Out:
# Location
# Thane          275
# Kharghar       105
# Goregaon        29
# Chembur         29
# Kandivali       24
#               ...
# Patel Nagar      1
# Kalamboli        1
# Kalyan           1
# Pant Nagar       1
# 4 Bunglows       1
# Name: Location, Length: 150, dtype: int64

# %%
len(location_stats[location_stats<=5])
# Out:
# 128

# %%
location_stats_less_than_5 = location_stats[location_stats<=5]
location_stats_less_than_5
# Out:
# Location
# Dahisar          5
# Thane West       5
# Borivali East    5
# Virar            5
# Parel            5
#                 ..
# Patel Nagar      1
# Kalamboli        1
# Kalyan           1
# Pant Nagar       1
# 4 Bunglows       1
# Name: Location, Length: 128, dtype: int64

# %%
len(df3.Location.unique())
# Out:
# 150

# %%
df3.location = df3.Location.apply(lambda x: 'other' if x in location_stats_less_than_5 else x)
len(df3.Location.unique())
# Out:
# <ipython-input-23-f58b1395c871>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df3.location = df3.Location.apply(lambda x: 'other' if x in location_stats_less_than_5 else x)
# 150

# %%
df3.head(10)
# Out:
#     Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0  Mira Road   700   4760000           1    1    1            1             0
# 1   Goregaon  1296  18100000           1    2    1            1             1
# 2   Goregaon  1638  23800000           1    3    1            1             1
# 3   Goregaon  1465  21200000           1    3    1            1             1
# 4   Borivali   700   8600000           1    1    1            1             1
# 5   Goregaon  2030  36500000           1    3    1            1             1
# 6      Malad  1450  23700000           1    3    1            1             0
# 7      Malad  1100  21400000           1    2    1            1             1
# 8  Kandivali   800  12500000           1    2    1            1             1
# 9  Kandivali  1500  18000000           1    3    1            1             1
#
#    Jogging_Track  price_per_sqrt
# 0              0     6800.000000
# 1              1    13966.049383
# ...

# %%
df3[df2.Area/df3.bhk<275]
# Out:
#         Location  Area    Price  New/Resale  bhk  Gym  Car_Parking  \
# 353  Godrej Hill   534  5200000           0    2    0            1
# 372    Mira Road   245  2100000           1    1    0            1
# 488       mumbai   400  3500000           0    2    1            1
# 505        Thane   547  6800000           0    2    1            1
# 639        Thane   239  4900000           1    1    1            0
# 643        Thane   400  7598999           1    2    1            0
#
#      Indoor_Games  Jogging_Track  price_per_sqrt
# 353             0              0     9737.827715
# 372             0              0     8571.428571
# 488             0              0     8750.000000
# 505             0              0    12431.444241
# 639             0              1    20502.092050
# 643             0              0    18997.497500

# %%
df3.shape
# Out:
# (858, 10)

# %%
df4 = df3[~(df3.Area/df3.bhk<250)]
df4.shape
# Out:
# (854, 10)

# %%
df4.price_per_sqrt.describe()
# Out:
# count       854.000000
# mean      13569.102057
# std        9380.260569
# min        2050.000000
# 25%        8478.573713
# 50%       11428.571429
# 75%       16409.254808
# max      109950.522265
# Name: price_per_sqrt, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Location'):
        m = np.mean(subdf.price_per_sqrt)
        st = np.std(subdf.price_per_sqrt)
        reduced_df = subdf[(subdf.price_per_sqrt>(m-st)) & (subdf.price_per_sqrt<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out
df5 = remove_pps_outliers(df4)
df5.shape
# Out:
# (576, 10)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_price_vs_bed(df):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(data=df, x='bhk', y='Price', hue='Price', palette='viridis', size='Price', sizes=(20, 200))
    plt.title('Price vs Bedrooms')
    plt.xlabel('Bedrooms')
    plt.ylabel('Price (Lakh Indian Rupees)')
    plt.show()

# Call the function with your DataFrame
plot_price_vs_bed(df5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_price_vs_bed_bar(df):
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df, x='bhk', y='Price', palette='viridis')
    plt.title('Price vs Bedrooms')
    plt.xlabel('Bedrooms')
    plt.ylabel('Price (Lakh Indian Rupees)')
    plt.show()

# Call the function with your DataFrame
plot_price_vs_bed_bar(df5)
# Out:
# <ipython-input-31-0dd0db821f1f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='bhk', y='Price', palette='viridis')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_location_distribution(df):
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x='Location', palette='viridis')
    plt.title('Distribution of Locations')
    plt.xlabel('Location')
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
    plt.tight_layout()
    plt.show()

# Call the function with your DataFrame
plot_location_distribution(df5)
# Out:
# <ipython-input-32-b72422aa3bb6>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Location', palette='viridis')

# %%
import matplotlib.pyplot as plt

def plot_location_distribution_pie(df):
    plt.figure(figsize=(8, 8))
    location_counts = df['Location'].value_counts().head(5)  # Select only the first five locations
    plt.pie(location_counts, labels=location_counts.index, autopct='%1.1f%%', startangle=140)
    plt.title('Distribution of Locations')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
    plt.show()

# Call the function with your DataFrame
plot_location_distribution_pie(df5)

# %%
def plot_scatter_chart(df,location):
    bhk2 = df[(df.Location==location) & (df.bhk==2)]
    bhk3 = df[(df.Location==location) & (df.bhk==3)]
    matplotlib.rcParams['figure.figsize'] = (15,10)
    plt.scatter(bhk2.Area,bhk2.Price,color='blue',label='2 BHK', s=50)
    plt.scatter(bhk3.Area,bhk3.Price,marker='+', color='green',label='3 BHK', s=50)
    plt.xlabel("Total Square Feet Area")
    plt.ylabel("Price (Lakh Indian Rupees)")
    plt.title(location)
    plt.legend()

plot_scatter_chart(df5,"Kharghar")

# %%
import matplotlib.pyplot as plt

def plot_price_vs_area(df):
    plt.figure(figsize=(10, 6))
    plt.scatter(df['Area'], df['Price'], alpha=0.5)
    plt.title('Price vs. Area')
    plt.xlabel('Area')
    plt.ylabel('Price (Lakh Indian Rupees)')
    plt.grid(True)
    plt.show()

# Call the function with your DataFrame
plot_price_vs_area(df5)

# %%
plot_scatter_chart(df5,"Thane")

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('Location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqrt),
                'std': np.std(bhk_df.price_per_sqrt),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqrt<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df6 = remove_bhk_outliers(df5)
df6.shape
# Out:
# (453, 10)

# %%
plot_scatter_chart(df6,"Thane")

# %%
import matplotlib
matplotlib.rcParams["figure.figsize"] = (20,8)
plt.hist(df6.price_per_sqrt,rwidth=0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df6.head(2)
# Out:
#   Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0   Airoli   450   5500000           0    1    0            1             0
# 1   Airoli  1245  14900000           1    2    0            1             0
#
#    Jogging_Track  price_per_sqrt
# 0              0    12222.222222
# 1              0    11967.871486

# %%
df7 = df6.drop(['price_per_sqrt'],axis='columns')
df7.head(3)
# Out:
#   Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0   Airoli   450   5500000           0    1    0            1             0
# 1   Airoli  1245  14900000           1    2    0            1             0
# 2   Airoli  1183  14000000           1    2    1            1             1
#
#    Jogging_Track
# 0              0
# 1              0
# 2              1

# %%
dummies = pd.get_dummies(df7.Location)
dummies.head(3)
# Out:
#    Airoli  Andheri  Badlapur  Belapur  Bhandup  Borivali  Borivali East  \
# 0    True    False     False    False    False     False          False
# 1    True    False     False    False    False     False          False
# 2    True    False     False    False    False     False          False
#
#    Borivali West  Chembur  Dahisar  ...   Ulwe  Vasai  Vikhroli  Virar  \
# 0          False    False    False  ...  False  False     False  False
# 1          False    False    False  ...  False  False     False  False
# 2          False    False    False  ...  False  False     False  False
#
#    Wadala  Worli  Yari Road  kandivali  mumbai  raheja vihar
# 0   False  False      False      False   False         False
# 1   False  False      False      False   False         False
# 2   False  False      False      False   False         False
#
# [3 rows x 65 columns]

# %%
df8 = pd.concat([df7],axis='columns')
df8.head(3)
# Out:
#   Location  Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0   Airoli   450   5500000           0    1    0            1             0
# 1   Airoli  1245  14900000           1    2    0            1             0
# 2   Airoli  1183  14000000           1    2    1            1             1
#
#    Jogging_Track
# 0              0
# 1              0
# 2              1

# %%
df9 = df8.drop('Location',axis='columns')
df9.head(2)
# Out:
#    Area     Price  New/Resale  bhk  Gym  Car_Parking  Indoor_Games  \
# 0   450   5500000           0    1    0            1             0
# 1  1245  14900000           1    2    0            1             0
#
#    Jogging_Track
# 0              0
# 1              0

# %%
df9.shape
# Out:
# (453, 8)

# %%
x = df9.drop(["Price", "Gym",'Car_Parking',"Indoor_Games","Jogging_Track","New/Resale"], axis=1)
y = df9['Price']

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import pickle as pkl

# Splitting data
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0, train_size=0.8)

# Defining models
models = {
    "Random Forest": RandomForestRegressor(),
    "Gradient Boosting": GradientBoostingRegressor(),
    "SVR": SVR(),
    "Linear Regression": LinearRegression()
}

# Training and evaluating models
results = {}
for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    score = r2_score(y_test, y_pred)
    results[name] = score
    print(f"{name}: R2 Score = {score}")

# Saving the best model
best_model_name = max(results, key=results.get)
best_model = models[best_model_name]
pkl.dump(best_model, open('model.pkl', 'wb'))
print(f"Best model: {best_model_name}")

# Comparing results
plt.bar(results.keys(), results.values())
plt.ylabel('R2 Score')
plt.title('Comparison of Regression Models')
plt.show()
# Out:
# Random Forest: R2 Score = 0.55986642138197
# Gradient Boosting: R2 Score = 0.4907490204724484
# SVR: R2 Score = -0.06667495329726947
# Linear Regression: R2 Score = 0.6105258133625282
# Best model: Linear Regression
